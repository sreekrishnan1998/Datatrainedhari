# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Reading Dataset

# %%
#Reading the csv file with pandas
df=pd.read_csv('/content/Grades.csv')

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
#shape of the dataset
df.shape
# Out:
# (571, 43)

# %%
# columns names
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
#Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
#  19  CS-214     565 non-null    object
#  20  EE-217     565 non-null    object
#  21  CS-212     565 non-null    object
#  22  CS-215     565 non-null    object
#  23  MT-331     562 non-null    object
#  24  EF-303     561 non-null    object
#  25  HS-304     561 non-null    object
#  26  CS-301     561 non-null    object
#  27  CS-302     561 non-null    object
#  28  TC-383     561 non-null    object
#  29  MT-442     561 non-null    object
#  30  EL-332     562 non-null    object
#  31  CS-318     562 non-null    object
#  32  CS-306     562 non-null    object
#  33  CS-312     561 non-null    object
#  34  CS-317     559 non-null    object
#  35  CS-403     559 non-null    object
#  36  CS-421     559 non-null    object
#  37  CS-406     486 non-null    object
#  38  CS-414     558 non-null    object
#  39  CS-419     558 non-null    object
#  40  CS-423     557 non-null    object
#  41  CS-412     492 non-null    object
#  42  CGPA       571 non-null    float64
# dtypes: float64(1), object(42)
# memory usage: 191.9+ KB

# %% [markdown]
# Datatype of all first 42  columns are object and categorical variables.Wheras the column "CGPA" is a continous variable

# %%
#Droping  the Seat no column
df=df.drop(columns=['Seat No.'],axis=1)
df.shape
# Out:
# (571, 42)

# %% [markdown]
# # Detecting Null Values

# %%
#Detecting total null values in each column
df.isna().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
#tOtal null values present in column in %
missing_values = df.isna().sum()/df.shape[0]*100
missing_values.sort_values(ascending=False)
# Out:
# CS-406       14.886165
# CS-412       13.835377
# CS-423        2.451839
# CS-419        2.276708
# CS-414        2.276708
# CS-403        2.101576
# CS-317        2.101576
# CS-421        2.101576
# EF-303        1.751313
# HS-304        1.751313
# CS-301        1.751313
# CS-302        1.751313
# MT-442        1.751313
# TC-383        1.751313
# CS-312        1.751313
# MT-331        1.576182
# EL-332        1.576182
# CS-318        1.576182
# CS-306        1.576182
# MT-224        1.225919
# CS-210        1.225919
# EE-222        1.225919
# CS-215        1.050788
# CS-212        1.050788
# CS-214        1.050788
# EE-217        1.050788
# CS-203        0.875657
# CS-211        0.875657
# MT-222        0.875657
# HS-205/20     0.875657
# CS-107        0.350263
# ME-107        0.350263
# EE-119        0.350263
# EL-102        0.350263
# CS-106        0.350263
# MT-111        0.350263
# HS-105/12     0.175131
# CY-105        0.175131
# PH-121        0.000000
# HS-101        0.000000
# CS-105        0.000000
# CGPA          0.000000
# dtype: float64

# %%
# Filling null values with the mode of each column
df1= df.apply(lambda x: x.fillna(x.mode().iloc[0]))

# %%
#CHecking for null values
df1.isna().sum()
# Out:
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# No null values exists in the dataset now.

# %% [markdown]
# #Plotting Countplot for all categorical columns

# %%
sns.set(style="whitegrid")

# Loop through all columns in the DataFrame and plot count plots
for column in df1.columns:
    plt.figure(figsize=(8, 5))  # Adjust figure size if needed
    sns.countplot(x=column, data=df1)
    plt.title(f'Count Plot for {column}')
    plt.show()

# %% [markdown]
# #Label Encoder

# %%
#Coverting cat variables to integers
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df1.columns:
    if df1[col].dtype == 'O':
        df1[col] = le.fit_transform(df1[col])

# %%
df1
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# 0         5       8  ...       8       8       8       8       2       0
# 1        10       9  ...      10       9       6       9       2       5
# 2         2       2  ...       3       3       0       6       0       0
# 3         9       7  ...      10       6      10       8       5       3
# 4         0       2  ...       5       4       4       5       2       0
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 566       1       4  ...       2       2       0       0       0       4
# 567       0       0  ...       4       4       0       0       2       3
# 568       0       3  ...       2       3       0       4       0       6
# 569       5       8  ...       9       3       3       8       9       6
# 570       6      10  ...       7       6       5       9      11       8
#
#      CS-419  CS-423  CS-412   CGPA
# 0         8       3       2  2.205
# 1         6       6       3  2.008
# 2         0       2       0  3.608
# 3         7       7       7  1.906
# 4         2       2       0  3.448
# ..      ...     ...     ...    ...
# 566       4       3       0  3.798
# 567       2       6       2  3.772
# 568       4       2       2  3.470
# 569       3       5       6  2.193
# 570       4       9       8  1.753
#
# [571 rows x 42 columns]

# %%
#Box Plot
plt.figure(figsize=(20,25))
p=1
for i in df1:
  if not df1[i].dtype == 'object':
    plt.subplot(11,4,p)
    sns.boxplot(df1[i].to_frame())
    plt.xlabel(i)
  p+=1
plt.show()

# %%
#Removing Outliers Using IQR
q1 = df1.quantile(0.25)
q3 = df1.quantile(0.75)
IQR = q3 - q1
df2 = df1[~((df1 < (q1 - 1.5 * IQR)) | (df1 > (q3 + 1.5 * IQR))).any(axis=1)]
df2.shape
# Out:
# (438, 42)

# %%
#Distribution Plot
plt.figure(figsize=(20,25))
p=1
for i in df2:
  if not df2[i].dtype == 'object':
    plt.subplot(11,4,p)
    sns.distplot(df2[i].to_frame())
    plt.xlabel(i)
  p+=1
plt.show()

# %%
#CHecking for Skewness
df2.skew()
# Out:
# PH-121       0.754110
# HS-101       0.179542
# CY-105       1.219335
# HS-105/12    0.549997
# MT-111       0.653293
# CS-105       1.205573
# CS-106       0.547916
# EL-102       0.756778
# EE-119       0.706062
# ME-107       0.323498
# CS-107       0.700390
# HS-205/20    0.440220
# MT-222       0.442504
# EE-222       0.999684
# MT-224       0.686267
# CS-210       0.492728
# CS-211       0.283687
# CS-203       0.490039
# CS-214       0.200454
# EE-217       0.639378
# CS-212       0.583936
# CS-215       0.330863
# MT-331       0.812856
# EF-303       0.478923
# HS-304       0.447433
# CS-301       0.624771
# CS-302       0.401435
# TC-383       0.547372
# MT-442       0.820042
# EL-332       0.482780
# CS-318       0.379329
# CS-306       0.504063
# CS-312       0.613774
# CS-317       0.190062
# CS-403       0.816215
# CS-421       0.171115
# CS-406       0.792407
# CS-414       1.101581
# CS-419       0.222519
# CS-423       0.605203
# CS-412       0.552450
# CGPA        -0.384054
# dtype: float64

# %%
#Selecting feature and target variables
x=df2.drop(['CGPA'],axis=1)
y=df2['CGPA']

# %% [markdown]
# #checking for multi-collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['Features'] = x.columns
vif
# Out:
#     VIF Factor   Features
# 0     5.663976     PH-121
# 1     6.744789     HS-101
# 2     4.018710     CY-105
# 3     5.147922  HS-105/12
# 4     5.500118     MT-111
# 5     4.734385     CS-105
# 6     5.790264     CS-106
# 7     4.251667     EL-102
# 8     5.754434     EE-119
# 9     6.154390     ME-107
# 10    4.806048     CS-107
# 11    4.180964  HS-205/20
# 12    5.178725     MT-222
# 13    4.658099     EE-222
# 14    6.855025     MT-224
# 15    6.965982     CS-210
# 16    8.626347     CS-211
# 17    6.807084     CS-203
# 18    9.620089     CS-214
# 19    5.222821     EE-217
# 20    9.578895     CS-212
# 21    9.369637     CS-215
# 22    4.878970     MT-331
axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['Features'] = x.columns
vif
# Out:
#     VIF Factor   Features
# 0     5.132008     PH-121
# 1     5.722112     HS-101
# 2     3.875540     CY-105
# 3     4.816522  HS-105/12
# 4     5.086927     MT-111
# 5     4.463999     CS-105
# 6     5.263452     CS-106
# 7     4.065099     EL-102
# 8     5.389255     EE-119
# 9     5.808613     ME-107
# 10    4.522264     CS-107
# 11    4.009184  HS-205/20
# 12    4.974191     MT-222
# 13    4.146047     EE-222
# 14    6.274503     MT-224
# 15    6.355842     CS-210
# 16    6.386287     CS-203
# 17    4.547178     EE-217
# 18    4.084253     MT-331
# 19    6.722677     EF-303
# 20    6.307945     CS-302
# 21    6.243532     TC-383
# 22    3.931751     MT-442
# 23    4.626399     CS-403
# 24    4.932387     CS-406
# 25    3.612367     CS-414
# 26    6.122705     CS-423
# 27    5.892414     CS-412

# %% [markdown]
# #Model Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#finding best random state
maxAcc=0
maxRs=0

for i in range(1,200):
  x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=i)
  lr=LinearRegression()
  lr.fit(x_train,y_train)
  pred=lr.predict(x_test)
  acc=r2_score(y_test,pred)
  if acc>maxAcc:
    maxAcc=acc
    maxRs=i
print('Best Accuracy', maxAcc, 'random_state is', maxRs)
# Out:
# Best Accuracy 0.9691458203325062 random_state is 83

# %%
#train and test data split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=112)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso, Ridge

# %%
#Linear Regression
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
print('R2 Score',r2_score(y_test,pred_lr))
print('MAE',mean_absolute_error(y_test,pred_lr))
print('MSE',mean_squared_error(y_test,pred_lr))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2 Score 0.9391624319895706
# MAE 0.08104669700639425
# MSE 0.01192629894027203
# RMSE 0.1092075956162026

# %%
#Regression pLot
plt.scatter(x=pred_lr,y=y_test,color='red')
plt.plot(pred_lr,pred_lr,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_lr')
plt.show()

# %%
#RandomForestRegression
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred_rfr=rfr.predict(x_test)
print('R2 Score',r2_score(y_test,pred_rfr))
print('MAE',mean_absolute_error(y_test,pred_rfr))
print('MSE',mean_squared_error(y_test,pred_rfr))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_rfr)))
# Out:
# R2 Score 0.9005018063740501
# MAE 0.10330560606060611
# MSE 0.019505138683333343
# RMSE 0.13966079866352385

# %%
#Regression PLot
plt.scatter(x=pred_rfr,y=y_test,color='red')
plt.plot(pred_rfr,pred_rfr,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_rfr')
plt.show()

# %%
#KNN Regression
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
print('R2 Score',r2_score(y_test,pred_knn))
print('MAE',mean_absolute_error(y_test,pred_knn))
print('MSE',mean_squared_error(y_test,pred_knn))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 Score 0.9013951276037178
# MAE 0.10602424242424242
# MSE 0.019330016363636373
# RMSE 0.13903242917980096

# %%
#Regression Plot
plt.scatter(x=pred_knn,y=y_test,color='red')
plt.plot(pred_knn,pred_knn,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_knn')
plt.show()

# %%
#GradientBoostingRegression
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr=gbr.predict(x_test)
print('R2 Score',r2_score(y_test,pred_gbr))
print('MAE',mean_absolute_error(y_test,pred_gbr))
print('MSE',mean_squared_error(y_test,pred_gbr))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# R2 Score 0.9192051498839406
# MAE 0.0943251210483153
# MSE 0.015838626802988084
# RMSE 0.12585160627893505

# %%
#Regression PLot
plt.scatter(x=pred_gbr,y=y_test,color='red')
plt.plot(pred_gbr,pred_gbr,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_gbr')
plt.show()

# %%
#Lasso
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
print('R2 Score',r2_score(y_test,pred_lasso))
print('MAE',mean_absolute_error(y_test,pred_lasso))
print('MSE',mean_squared_error(y_test,pred_lasso))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 Score -0.0016391811436193837
# MAE 0.3669040899187958
# MSE 0.19635644052306997
# RMSE 0.4431212481060573

# %%
plt.scatter(x=pred_lasso,y=y_test,color='red')
plt.plot(pred_lasso,pred_lasso,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_lasso')
plt.show()

# %%
#Ridge
ridge=Ridge()
ridge.fit(x_train,y_train)
pred_ridge=ridge.predict(x_test)
print('R2 Score',r2_score(y_test,pred_ridge))
print('MAE',mean_absolute_error(y_test,pred_ridge))
print('MSE',mean_squared_error(y_test,pred_ridge))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_ridge)))
# Out:
# R2 Score 0.9391982577115989
# MAE 0.08103047416717753
# MSE 0.011919275841147044
# RMSE 0.10917543607033152

# %%
#PLot
plt.scatter(x=pred_ridge,y=y_test,color='red')
plt.plot(pred_ridge,pred_ridge,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_ridge')
plt.show()

# %%
#Decision Tree
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
print('R2 Score',r2_score(y_test,pred_dtr))
print('MAE',mean_absolute_error(y_test,pred_dtr))
print('MSE',mean_squared_error(y_test,pred_dtr))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 Score 0.5543848109489717
# MAE 0.2254772727272727
# MSE 0.08735621969696969
# RMSE 0.29556085616496935

# %%
#Plot
plt.scatter(x=pred_dtr,y=y_test,color='red')
plt.plot(pred_dtr,pred_dtr,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_dtr')
plt.show()

# %%
#SVR
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print('R2 Score',r2_score(y_test,pred_svr))
print('MAE',mean_absolute_error(y_test,pred_svr))
print('MSE',mean_squared_error(y_test,pred_svr))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 Score 0.9277156104522141
# MAE 0.09529694561773383
# MSE 0.014170277784841496
# RMSE 0.11903897590638747

# %%
#PLOT
plt.scatter(x=pred_svr,y=y_test,color='red')
plt.plot(pred_svr,pred_svr,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_svr')
plt.show()

# %%
#Extra TRees
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
print('R2 Score',r2_score(y_test,pred_etr))
print('MAE',mean_absolute_error(y_test,pred_etr))
print('MSE',mean_squared_error(y_test,pred_etr))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 Score 0.9018191860359144
# MAE 0.10302856060606061
# MSE 0.01924688602500001
# RMSE 0.13873314681430682

# %%
#pLot
plt.scatter(x=pred_etr,y=y_test,color='red')
plt.plot(pred_etr,pred_etr,color='blue')
plt.xlabel('y_test')
plt.ylabel('pred_etr')
plt.show()

# %% [markdown]
# #Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
#score for Linear Regression
score=cross_val_score(lr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_lr)) - score.mean())
# Out:
# [0.81698084 0.95806603 0.9345411  0.95042594 0.9293296 ]
# 0.9178687026104357
# Difference between R2 score and cross valication score is 0.021293729379134874

# %%
#score for RandomForest Regression
score=cross_val_score(rfr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_rfr)) - score.mean())
# Out:
# [0.75384931 0.89932561 0.88470003 0.88274824 0.87663176]
# 0.8594509907128762
# Difference between R2 score and cross valication score is 0.041050815661173856

# %%
#score for KNN
score=cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_knn)) - score.mean())
# Out:
# [0.81402753 0.89125005 0.92166623 0.85304775 0.89067134]
# 0.8741325789682802
# Difference between R2 score and cross valication score is 0.027262548635437533

# %%
#score for GradientBoostingRegression
score=cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_gbr)) - score.mean())
# Out:
# [0.76594939 0.92565994 0.89846548 0.9075952  0.9234875 ]
# 0.8842315015891782
# Difference between R2 score and cross valication score is 0.03497364829476246

# %%
#score for Lasso
score=cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_lasso)) - score.mean())
# Out:
# [-0.03338327 -0.00562555 -0.01430144 -0.02218687 -0.08776832]
# -0.03265309049813618
# Difference between R2 score and cross valication score is 0.031013909354516797

# %%
#score for Ridge
score=cross_val_score(ridge,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_ridge)) - score.mean())
# Out:
# [0.81700452 0.95808711 0.93457838 0.95043264 0.92939964]
# 0.9179004581222644
# Difference between R2 score and cross valication score is 0.021297799589334532

# %%
#score for DecisionTreeRegressor
score=cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_dtr)) - score.mean())
# Out:
# [0.6858776  0.62405034 0.69057675 0.48892661 0.60652393]
# 0.6191910457994265
# Difference between R2 score and cross valication score is -0.06480623485045478

# %%
#score for SVR
score=cross_val_score(svr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_svr)) - score.mean())
# Out:
# [0.82159638 0.94553512 0.9267721  0.89510492 0.91115338]
# 0.9000323790504264
# Difference between R2 score and cross valication score is 0.027683231401787634

# %%
#score for ExtratreeRegressor
score=cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross valication score is', (r2_score(y_test,pred_etr)) - score.mean())
# Out:
# [0.77813476 0.91681303 0.90803115 0.90289091 0.88915697]
# 0.8790053653171107
# Difference between R2 score and cross valication score is 0.022813820718803668

# %% [markdown]
# Ridge Rigression performs best

# %% [markdown]
# #Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
# Hyperparameter tuning
parameters = {'alpha': [0.001, 0.01, 0.1, 1, 10],
              'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
              'random_state': [1, 10, 20]}
grid_search = GridSearchCV(Ridge(), parameters, cv=5)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10],
#                          'random_state': [1, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga']})

# %%
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'alpha': 10, 'random_state': 10, 'solver': 'saga'}
# Best score: 0.9154740553738533

# %%
#fitting the model with best hyperparameter
model=Ridge(alpha= 10,random_state= 10, solver='saga')

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2 Score',r2_score(y_test,pred))
print('MAE',mean_absolute_error(y_test,pred))
print('MSE',mean_squared_error(y_test,pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score 0.9395136364628234
# MAE 0.08089009326595947
# MSE 0.011857450535016014
# RMSE 0.10889192134872087

# %%
result=model.score(x_test,y_test)
result
# Out:
# 0.9395136364628234

# %%
conclusion=pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=['Predicted','Orginal'])

# %%
#Result Validation
conclusion
# Out:
#                 0         1        2         3         4         5    \
# Predicted  3.560487  3.053689  2.95608  2.897596  2.899808  3.854869
# Orginal    3.585000  3.019000  3.09400  2.851000  3.167000  3.798000
#
#                 6         7         8        9    ...       122       123  \
# Predicted  3.158233  3.128907  2.578223  2.48517  ...  3.562174  2.754267
# Orginal    3.164000  3.261000  2.655000  2.51200  ...  3.476000  2.611000
#
#                 124       125       126       127       128       129  \
# Predicted  2.878578  2.884603  3.401534  2.793399  2.198936  3.610098
# Orginal    3.033000  2.784000  2.943000  2.715000  2.087000  3.651000
#
#                 130      131
# Predicted  3.088725  3.59885
# Orginal    3.010000  3.58300
#
# [2 rows x 132 columns]
