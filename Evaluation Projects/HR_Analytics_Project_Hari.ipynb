# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#REading the csv file
df=pd.read_csv('/content/HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
for i, column in enumerate(df.select_dtypes(include='object').columns):
    plt.figure(i)
    sns.countplot(x=column, data=df)
    plt.show()

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
df.groupby(['JobRole'])['Attrition'].value_counts().to_frame()
# Out:
#                                      Attrition
# JobRole                   Attrition
# Healthcare Representative No               122
#                           Yes                9
# Human Resources           No                40
#                           Yes               12
# Laboratory Technician     No               197
#                           Yes               62
# Manager                   No                97
#                           Yes                5
# Manufacturing Director    No               135
#                           Yes               10
# Research Director         No                78
#                           Yes                2
# Research Scientist        No               245
#                           Yes               47
# Sales Executive           No               269
#                           Yes               57
# Sales Representative      No                50
#                           Yes               33

# %%
df.groupby(['Department'])['Attrition'].value_counts().to_frame()
# Out:
#                                   Attrition
# Department             Attrition
# Human Resources        No                51
#                        Yes               12
# Research & Development No               828
#                        Yes              133
# Sales                  No               354
#                        Yes               92

# %%
df.groupby(['EducationField'])['Attrition'].value_counts().to_frame()
# Out:
#                             Attrition
# EducationField   Attrition
# Human Resources  No                20
#                  Yes                7
# Life Sciences    No               517
#                  Yes               89
# Marketing        No               124
#                  Yes               35
# Medical          No               401
#                  Yes               63
# Other            No                71
#                  Yes               11
# Technical Degree No               100
#                  Yes               32

# %%
df.groupby(['Gender'])['Attrition'].value_counts().to_frame()
# Out:
#                   Attrition
# Gender Attrition
# Female No               501
#        Yes               87
# Male   No               732
#        Yes              150

# %%
# Create a bar chart of Attrition vs Gender
sns.barplot(x='Attrition', y='Gender', data=df)
plt.show()

# %%
# Create a pie chart of Attrition vs Department
labels = df['Department'].value_counts().index.to_list()
sizes = df['Department'].value_counts().to_list()
colors = sns.color_palette('husl', len(labels))
plt.pie(sizes, labels=labels, colors=colors, autopct='%.1f%%')
plt.show()

# %%
# Create a boxplot of Age vs Attrition
sns.boxplot(x='Attrition', y='Age', data=df)
plt.show()

# %%
sns.countplot(x='Attrition', hue='Department', data=df)
plt.show()

# %%
sns.countplot(x='Attrition', hue='JobRole', data=df)
plt.show()

# %%
sns.countplot(x='Attrition', hue='EducationField', data=df)
plt.show()

# %%
# Create a scatter plot of Age vs DailyRate, colored by Attrition
sns.scatterplot(x='Age', y='DailyRate', hue='Attrition', data=df)
plt.show()

# %%
df.nunique().to_frame('No of customers')
# Out:
#                           No of customers
# Age                                    43
# Attrition                               2
# BusinessTravel                          3
# DailyRate                             886
# Department                              3
# DistanceFromHome                       29
# Education                               5
# EducationField                          6
# EmployeeCount                           1
# EmployeeNumber                       1470
# EnvironmentSatisfaction                 4
# Gender                                  2
# HourlyRate                             71
# JobInvolvement                          4
# JobLevel                                5
# JobRole                                 9
# JobSatisfaction                         4
# MaritalStatus                           3
# MonthlyIncome                        1349
# MonthlyRate                          1427
# NumCompaniesWorked                     10
# ...

# %%
#Assigning numeric values for preprocessing data

df['Attrition'] = df['Attrition'].map({'No':0, 'Yes':1})
df['Gender'] = df['Gender'].map({'Male':0, 'Female':1})

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(data=df)
plt.title('Boxplot of all columns')
plt.show()

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                      0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# ...

# %%
#distribution plot
plt.figure(figsize=(10, 6),facecolor='white')
plotnumber = 1

for i in df:
  if df[i].dtype != 'O':
      if plotnumber <= 12:
          ax = plt.subplot(4, 3, plotnumber)
          sns.distplot(df[i], color='m')  # Use histplot instead of displot for individual axes
          plt.xlabel(i)
          plt.yticks(rotation=0, fontsize=10)
      plotnumber += 1

plt.tight_layout()
plt.show()

# %%
#changing cat val to digits
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df.columns:
    if df[col].dtype == 'O':
        df[col] = le.fit_transform(df[col])

# %%
df.shape
# Out:
# (1470, 35)

# %%
x=df.drop('Attrition',axis=1)
y=df['Attrition']

# %% [markdown]
# #Oversampling

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x1,y1=SM.fit_resample(x,y)

# %%
#STandazing the data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x1=pd.DataFrame(scaler.fit_transform(x1),columns=x1.columns)

# %%
x1.describe()
# Out:
#                 Age  BusinessTravel     DailyRate    Department  \
# count  2.466000e+03    2.466000e+03  2.466000e+03  2.466000e+03
# mean  -1.613560e-16   -5.762715e-17  5.762715e-17 -6.915258e-17
# std    1.000203e+00    1.000203e+00  1.000203e+00  1.000203e+00
# min   -1.963591e+00   -2.314323e+00 -1.788611e+00 -2.276317e+00
# 25%   -7.288186e-01   -7.875384e-01 -8.294191e-01 -3.572067e-01
# 50%   -1.675586e-01    7.392459e-01 -7.501375e-02 -3.572067e-01
# 75%    6.182053e-01    7.392459e-01  8.366145e-01 -3.572067e-01
# max    2.750993e+00    7.392459e-01  1.902823e+00  1.561904e+00
#
#        DistanceFromHome     Education  EducationField  EmployeeCount  \
# count      2.466000e+03  2.466000e+03    2.466000e+03         2466.0
# mean      -6.338986e-17 -1.728814e-16   -2.881357e-17            0.0
# std        1.000203e+00  1.000203e+00    1.000203e+00            0.0
# min       -1.131405e+00 -1.797399e+00   -1.707703e+00            0.0
# ...

# %%
x1.skew()
# Out:
# Age                         0.517095
# BusinessTravel             -1.015870
# DailyRate                   0.108218
# Department                  0.198509
# DistanceFromHome            0.814584
# Education                  -0.115580
# EducationField              0.625737
# EmployeeCount               0.000000
# EmployeeNumber              0.027890
# EnvironmentSatisfaction     0.036538
# Gender                      0.898452
# HourlyRate                  0.019492
# JobInvolvement             -0.332694
# JobLevel                    1.260483
# JobRole                    -0.335175
# JobSatisfaction            -0.064380
# MaritalStatus              -0.101715
# MonthlyIncome               1.579452
# MonthlyRate                -0.000684
# NumCompaniesWorked          1.009314
# Over18                      0.000000
# OverTime                    0.935172
# PercentSalaryHike           0.825468
# PerformanceRating           2.621014
# RelationshipSatisfaction   -0.072362
# ...

# %% [markdown]
# #VIF Factor

# %%
#VIF Factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
vif['Features'] = x1.columns
vif
# Out:
#     VIF Factor                  Features
# 0     2.085655                       Age
# 1     1.042748            BusinessTravel
# 2     1.046990                 DailyRate
# 3     1.923113                Department
# 4     1.038121          DistanceFromHome
# 5     1.096293                 Education
# 6     1.043087            EducationField
# 7          NaN             EmployeeCount
# 8     1.042616            EmployeeNumber
# 9     1.096471   EnvironmentSatisfaction
# 10    1.066523                    Gender
# 11    1.032240                HourlyRate
# 12    1.122033            JobInvolvement
# 13   10.723565                  JobLevel
# 14    1.830907                   JobRole
# 15    1.076143           JobSatisfaction
# 16    1.588964             MaritalStatus
# 17   10.107376             MonthlyIncome
# 18    1.057662               MonthlyRate
# 19    1.248152        NumCompaniesWorked
# 20         NaN                    Over18
# 21    1.040403                  OverTime
# ...

# %%
x1.drop('JobLevel',axis=1,inplace=True)

# %%
#VIF Factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
vif['Features'] = x1.columns
vif
# Out:
#     VIF Factor                  Features
# 0     2.084554                       Age
# 1     1.041620            BusinessTravel
# 2     1.046072                 DailyRate
# 3     1.861328                Department
# 4     1.032108          DistanceFromHome
# 5     1.095780                 Education
# 6     1.043055            EducationField
# 7          NaN             EmployeeCount
# 8     1.042461            EmployeeNumber
# 9     1.091467   EnvironmentSatisfaction
# 10    1.062524                    Gender
# 11    1.031726                HourlyRate
# 12    1.121247            JobInvolvement
# 13    1.816841                   JobRole
# 14    1.070953           JobSatisfaction
# 15    1.588733             MaritalStatus
# 16    2.740792             MonthlyIncome
# 17    1.055439               MonthlyRate
# 18    1.247491        NumCompaniesWorked
# 19         NaN                    Over18
# 20    1.038296                  OverTime
# 21    1.890240         PercentSalaryHike
# ...

# %%
x1.drop('TotalWorkingYears',axis=1,inplace=True)

# %%
#VIF Factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
vif['Features'] = x1.columns
vif
# Out:
#     VIF Factor                  Features
# 0     1.607423                       Age
# 1     1.040134            BusinessTravel
# 2     1.044740                 DailyRate
# 3     1.860817                Department
# 4     1.031832          DistanceFromHome
# 5     1.094621                 Education
# 6     1.041130            EducationField
# 7          NaN             EmployeeCount
# 8     1.041816            EmployeeNumber
# 9     1.090649   EnvironmentSatisfaction
# 10    1.061632                    Gender
# 11    1.031237                HourlyRate
# 12    1.121235            JobInvolvement
# 13    1.801877                   JobRole
# 14    1.070907           JobSatisfaction
# 15    1.584801             MaritalStatus
# 16    1.910853             MonthlyIncome
# 17    1.055145               MonthlyRate
# 18    1.187460        NumCompaniesWorked
# 19         NaN                    Over18
# 20    1.038291                  OverTime
# 21    1.889588         PercentSalaryHike
# ...

# %% [markdown]
# #Model Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

maxAcc=0
maxRs=0

for i in range(1,200):
  x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=.3,random_state=i)
  RFC=RandomForestClassifier()
  RFC.fit(x_train,y_train)
  pred=RFC.predict(x_test)
  acc=accuracy_score(y_test,pred)
  if acc>maxAcc:
    maxAcc=acc
    maxRs=i
print('Best Accuracy', maxAcc, 'random_state is', maxRs)
# Out:
# Best Accuracy 0.9351351351351351 random_state is 40

# %% [markdown]
# #Create Train Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=.3,random_state=maxRs)

# %% [markdown]
# #Classification Algorithms

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import accuracy_score,roc_curve,classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
#LogisticRegression
lg=LogisticRegression()
lg.fit(x_train,y_train)
pred_lg=lg.predict(x_test)
print(accuracy_score(y_test,pred_lg))
print(confusion_matrix(y_test,pred_lg))
print(classification_report(y_test,pred_lg))
# Out:
# 0.8351351351351352
# [[315  67]
#  [ 55 303]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84       382
#            1       0.82      0.85      0.83       358
#
#     accuracy                           0.84       740
#    macro avg       0.84      0.84      0.84       740
# weighted avg       0.84      0.84      0.84       740

# %%
#RandomForestClassifier
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
pred_RFC=RFC.predict(x_test)
print(accuracy_score(y_test,pred_RFC))
print(confusion_matrix(y_test,pred_RFC))
print(classification_report(y_test,pred_RFC))
# Out:
# 0.922972972972973
# [[349  33]
#  [ 24 334]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       382
#            1       0.91      0.93      0.92       358
#
#     accuracy                           0.92       740
#    macro avg       0.92      0.92      0.92       740
# weighted avg       0.92      0.92      0.92       740

# %%
#SVC
svc=SVC()
svc.fit(x_train,y_train)
pred_svc=svc.predict(x_test)
print(accuracy_score(y_test,pred_svc))
print(confusion_matrix(y_test,pred_svc))
print(classification_report(y_test,pred_svc))
# Out:
# 0.9
# [[348  34]
#  [ 40 318]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       382
#            1       0.90      0.89      0.90       358
#
#     accuracy                           0.90       740
#    macro avg       0.90      0.90      0.90       740
# weighted avg       0.90      0.90      0.90       740

# %%
#GradientBoostingClassifier
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
pred_GB=GB.predict(x_test)
print(accuracy_score(y_test,pred_GB))
print(confusion_matrix(y_test,pred_GB))
print(classification_report(y_test,pred_GB))
# Out:
# 0.8986486486486487
# [[338  44]
#  [ 31 327]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       382
#            1       0.88      0.91      0.90       358
#
#     accuracy                           0.90       740
#    macro avg       0.90      0.90      0.90       740
# weighted avg       0.90      0.90      0.90       740

# %%
#AdaBoostClassifier
Ada=AdaBoostClassifier()
Ada.fit(x_train,y_train)
pred_Ada=Ada.predict(x_test)
print(accuracy_score(y_test,pred_Ada))
print(confusion_matrix(y_test,pred_Ada))
print(classification_report(y_test,pred_Ada))
# Out:
# 0.8729729729729729
# [[331  51]
#  [ 43 315]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       382
#            1       0.86      0.88      0.87       358
#
#     accuracy                           0.87       740
#    macro avg       0.87      0.87      0.87       740
# weighted avg       0.87      0.87      0.87       740

# %%
#BaggingClassifier
bc=BaggingClassifier()
bc.fit(x_train,y_train)
pred_bc=bc.predict(x_test)
print(accuracy_score(y_test,pred_bc))
print(confusion_matrix(y_test,pred_bc))
print(classification_report(y_test,pred_bc))
# Out:
# 0.8783783783783784
# [[341  41]
#  [ 49 309]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       382
#            1       0.88      0.86      0.87       358
#
#     accuracy                           0.88       740
#    macro avg       0.88      0.88      0.88       740
# weighted avg       0.88      0.88      0.88       740

# %%
#ExtraTreeClassifier
from sklearn.tree import ExtraTreeClassifier
et=ExtraTreeClassifier()
et.fit(x_train,y_train)
pred_et=et.predict(x_test)
print(accuracy_score(y_test,pred_et))
print(confusion_matrix(y_test,pred_et))
print(classification_report(y_test,pred_et))
# Out:
# 0.8081081081081081
# [[285  97]
#  [ 45 313]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       382
#            1       0.76      0.87      0.82       358
#
#     accuracy                           0.81       740
#    macro avg       0.81      0.81      0.81       740
# weighted avg       0.82      0.81      0.81       740

# %%
#check cv score for randomforest

score=cross_val_score(final_model,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cross valication score is', accuracy_score(y_test,pred_RFC) - score.mean())
# Out:
# [0.67004049 0.93914807 0.92292089 0.92494929 0.57200811]
# 0.8058133709996633
# Difference between accuracy score and cross valication score is 0.11715960197330966

# %%
#check cv score for svc

score=cross_val_score(svc,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cross valication score is', accuracy_score(y_test,pred_svc) - score.mean())
# Out:
# [0.63765182 0.92494929 0.93711968 0.92089249 0.89046653]
# 0.8622159627497515
# Difference between accuracy score and cross valication score is 0.03778403725024848

# %%
#check cv score for Gradient Boosting

score=cross_val_score(GB,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cross valication score is', accuracy_score(y_test,pred_GB) - score.mean())
# Out:
# [0.4291498  0.78904665 0.72819473 0.71602434 0.53752535]
# 0.6399881745243119
# Difference between accuracy score and cross valication score is 0.2586604741243368

# %% [markdown]
# svc performs well

# %%
from sklearn.metrics import roc_auc_score

# Calculate the ROC AUC score for the SVC model
roc_auc = roc_auc_score(y_test, pred_svc)

# Plot the ROC AUC curve
plt.figure()
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='SVC (AUC = {:.2f})'.format(roc_auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC AUC Curve for SVC Model')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #Hyper Paramater Tuning

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
hyperparameters = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'gamma': [1, 0.1, 0.01, 0.001],  # Kernel coefficient
    'kernel': ['rbf', 'linear', 'poly', 'sigmoid']  # Kernel type
}

# %%
grid_search = GridSearchCV(SVC(), hyperparameters, cv=5)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf', 'linear', 'poly', 'sigmoid']})

# %%
# Get the best model and its parameters
best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

# Print the best model and its parameters
print("Best model:", best_model)
print("Best parameters:", best_params)
# Out:
# Best model: SVC(C=10, gamma=0.1)
# Best parameters: {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
final_model=SVC(C=10, gamma=0.1)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 94.05405405405406
